# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
green_08 = pd.read_csv("E:/uni/20sem2/MAST30034/Assignment1/green_tripdata_2018-08.csv")
#green_09 = pd.read_csv("E:/uni/20sem2/MAST30034/Assignment1/green_tripdata_2018-09.csv")

#yellow_08 = pd.read_csv("E:/uni/20sem2/MAST30034/Assignment1/yellow_tripdata_2018-08.csv")
#yellow_09 = pd.read_csv("E:/uni/20sem2/MAST30034/Assignment1/yellow_tripdata_2018-09.csv")

#fhv_08 = pd.read_csv("E:/uni/20sem2/MAST30034/Assignment1/fhv_tripdata_2018-08.csv")
#fhv_09 = pd.read_csv("E:/uni/20sem2/MAST30034/Assignment1/fhv_tripdata_2018-09.csv")


#df.reset_index().to_feather('../Data/Lab1/sample.feather')

# %%
# remove invaild data (passager == 0 and trip_distance = 0)
cleaned_green_08 = green_08[(green_08["passenger_count"] != 0) & (green_08["trip_distance"] != 0)]

# %%
cleaned_green_08 = green_08[(green_08['lpep_pickup_datetime'] > "2018-08-20 00:00:00") & (green_08['lpep_pickup_datetime'] < "2018-08-31 23:59:59") & (green_08["passenger_count"] != 0) & (green_08["trip_distance"] != 0)& (green_08["payment_type"] != 3)& (green_08["payment_type"] != 4)& (green_08["payment_type"] != 6)]

# %%
cleaned_green_08.sort_values(by = "total_amount")
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 656772         2  2018-08-31 17:03:02   2018-08-31 17:08:39
# 450986         2  2018-08-21 21:40:27   2018-08-21 21:44:20
# 569984         2  2018-08-27 16:15:13   2018-08-27 16:17:39
# 497731         2  2018-08-24 10:15:01   2018-08-24 10:17:39
# 541746         2  2018-08-26 04:44:20   2018-08-26 04:44:29
# ...          ...                  ...                   ...
# 583639         2  2018-08-28 10:27:18   2018-08-28 12:07:24
# 553504         2  2018-08-26 18:53:59   2018-08-27 00:00:00
# 501012         2  2018-08-24 13:04:24   2018-08-24 15:19:51
# 610859         2  2018-08-30 07:38:51   2018-08-30 07:38:51
# 482439         2  2018-08-25 08:54:55   2018-08-25 08:54:55
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 656772                  N           1           116           244
# 450986                  N           1           226           226
# 569984                  N           1           202           202
# 497731                  N           1           145           145
# 541746                  N           1           173           173
# ...                   ...         ...           ...           ...
# 583639                  N           4            70           138
# 553504                  N           4           213           265
# 501012                  N           4            93           265
# 610859                  N           1            49           133
# 482439                  N           1            33           252
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 656772                1           0.70         -5.5   -1.0     -0.5
# 450986                1           0.77         -5.0   -0.5     -0.5
# 569984                2           0.24         -3.5   -1.0     -0.5
# 497731                2           0.59         -4.0    0.0     -0.5
# 541746                1           0.01         -2.5   -0.5     -0.5
# ...                 ...            ...          ...    ...      ...
# 583639                1          65.99        286.0    0.0      0.5
# 553504                1          79.11        387.0    0.0      0.5
# 501012                1          73.58        369.5    0.0      0.5
# 610859                2           5.14        460.5    1.0      0.5
# 482439                3         151.13       1428.5    0.0      0.5
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 656772         0.0           0.0        NaN                   -0.3
# 450986         0.0           0.0        NaN                   -0.3
# 569984         0.0           0.0        NaN                   -0.3
# 497731         0.0           0.0        NaN                   -0.3
# 541746         0.0           0.0        NaN                   -0.3
# ...            ...           ...        ...                    ...
# 583639         0.0           0.0        NaN                    0.3
# 553504         0.0           0.0        NaN                    0.3
# 501012        25.0           0.0        NaN                    0.3
# 610859         0.0           0.0        NaN                    0.3
# 482439         0.0           0.0        NaN                    0.3
#
#         total_amount  payment_type  trip_type
# 656772          -7.3             2          1
# 450986          -6.3             2          1
# 569984          -5.3             2          1
# 497731          -4.8             2          1
# 541746          -3.8             2          1
# ...              ...           ...        ...
# 583639         286.8             2          1
# 553504         387.8             2          1
# 501012         395.3             1          1
# 610859         462.3             2          1
# 482439        1429.3             2          1
#
# [243690 rows x 19 columns]

# %%
cleaned_green_08[cleaned_green_08["payment_type"] == 4]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 418049         1  2018-08-20 00:35:15   2018-08-20 00:43:52
# 418153         1  2018-08-20 00:20:44   2018-08-20 00:20:51
# 418289         2  2018-08-20 00:34:28   2018-08-20 00:37:16
# 419216         2  2018-08-20 04:32:24   2018-08-20 04:36:08
# 420268         1  2018-08-20 07:36:48   2018-08-20 07:47:42
# ...          ...                  ...                   ...
# 665025         1  2018-08-31 22:25:08   2018-08-31 22:26:25
# 665629         2  2018-08-31 23:22:40   2018-08-31 23:25:46
# 665746         1  2018-08-31 23:05:49   2018-08-31 23:38:30
# 666119         1  2018-08-31 23:34:57   2018-09-01 00:02:24
# 666308         2  2018-08-31 23:31:16   2018-08-31 23:33:54
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 418049                  N           1           127            18
# 418153                  N           1            82            82
# 418289                  N           1            25            25
# 419216                  N           1           129           260
# 420268                  N           1            74           140
# ...                   ...         ...           ...           ...
# 665025                  N           1            93            93
# 665629                  N           1           260           260
# 665746                  N           1           181           230
# 666119                  N           1           255            79
# 666308                  N           1           112           112
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 418049                1           1.70          8.5    0.5      0.5
# 418153                1           1.60          2.5    0.5      0.5
# 418289                1           0.10         -3.5   -0.5     -0.5
# 419216                1           0.61         -4.5   -0.5     -0.5
# 420268                1           3.60         12.5    0.0      0.5
# ...                 ...            ...          ...    ...      ...
# 665025                1           9.90          3.0    0.5      0.5
# 665629                5           0.62         -4.5   -0.5     -0.5
# 665746                6           6.40         25.0    0.5      0.5
# 666119                1           6.10         22.0    0.5      0.5
# 666308                5           0.43         -4.0   -0.5     -0.5
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 418049         0.0           0.0        NaN                    0.3
# 418153         0.0           0.0        NaN                    0.3
# 418289         0.0           0.0        NaN                   -0.3
# 419216         0.0           0.0        NaN                   -0.3
# 420268         0.0           0.0        NaN                    0.3
# ...            ...           ...        ...                    ...
# 665025         0.0           0.0        NaN                    0.3
# 665629         0.0           0.0        NaN                   -0.3
# 665746         0.0           0.0        NaN                    0.3
# 666119         0.0           0.0        NaN                    0.3
# 666308         0.0           0.0        NaN                   -0.3
#
#         total_amount  payment_type  trip_type
# 418049           9.8             4          1
# 418153           3.8             4          1
# 418289          -4.8             4          1
# 419216          -5.8             4          1
# 420268          13.3             4          1
# ...              ...           ...        ...
# 665025           4.3             4          1
# 665629          -5.8             4          1
# 665746          26.3             4          1
# 666119          23.3             4          1
# 666308          -5.3             4          1
#
# [494 rows x 19 columns]

# %%
# Q1 sport event influence?
# 8.20 - 9.9
# 8.15 - 9.15

# %%
green_08
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              2  2018-08-01 00:03:22   2018-08-01 00:17:59
# 1              2  2018-08-01 00:37:08   2018-08-01 00:46:53
# 2              2  2018-08-01 00:12:45   2018-08-01 00:20:21
# 3              2  2018-08-01 00:21:29   2018-08-01 00:27:41
# 4              2  2018-08-01 00:03:24   2018-08-01 00:06:44
# ...          ...                  ...                   ...
# 666371         2  2018-08-31 23:24:01   2018-08-31 23:39:08
# 666372         2  2018-08-31 23:41:02   2018-08-31 23:55:08
# 666373         2  2018-08-31 23:57:44   2018-09-01 00:10:24
# 666374         2  2018-08-31 23:28:00   2018-08-31 23:29:37
# 666375         2  2018-08-31 23:07:47   2018-08-31 23:07:50
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N           1           255            49
# 1                       N           1           256           112
# 2                       N           1           146             7
# 3                       N           1             7           260
# 4                       N           1           256           256
# ...                   ...         ...           ...           ...
# 666371                  N           1            74            75
# 666372                  N           1            75            42
# 666373                  N           1            42            41
# 666374                  N           1           193           193
# 666375                  N           1           193           193
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 0                     1           3.54         13.5    0.5      0.5
# 1                     1           1.94          8.5    0.5      0.5
# 2                     2           1.37          7.0    0.5      0.5
# 3                     2           1.10          6.5    0.5      0.5
# 4                     1           0.56          4.5    0.5      0.5
# ...                 ...            ...          ...    ...      ...
# 666371                1           2.39         12.0    0.5      0.5
# 666372                1           2.68         12.0    0.5      0.5
# 666373                1           2.30         11.0    0.5      0.5
# 666374                1           0.00          0.0    0.0      0.0
# 666375                1           0.00          0.0    0.0      0.0
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 0             2.96           0.0        NaN                    0.3
# 1             1.96           0.0        NaN                    0.3
# 2             0.00           0.0        NaN                    0.3
# 3             0.00           0.0        NaN                    0.3
# 4             1.74           0.0        NaN                    0.3
# ...            ...           ...        ...                    ...
# 666371        0.00           0.0        NaN                    0.3
# 666372        0.00           0.0        NaN                    0.3
# 666373        0.00           0.0        NaN                    0.3
# 666374        0.00           0.0        NaN                    0.0
# 666375        0.00           0.0        NaN                    0.0
#
#         total_amount  payment_type  trip_type
# 0              17.76             1          1
# 1              11.76             1          1
# 2               8.30             2          1
# 3               7.80             2          1
# 4               7.54             1          1
# ...              ...           ...        ...
# 666371         13.30             2          1
# 666372         13.30             2          1
# 666373         12.30             2          1
# 666374          0.00             1          1
# 666375          0.00             1          1
#
# [666376 rows x 19 columns]
